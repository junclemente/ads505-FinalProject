# %%
import pandas as pd
import numpy as np

import httpimport 

from pathlib import Path

# %%
# Import personal library
with httpimport.github_repo('junclemente', 'jcds', ref='master'):
    import jcds.Quality as jq

# %%
datasets = Path('../datasets/')
df_file = 'loan_approval/SBAnational.csv'
df = pd.read_csv(datasets/df_file)
df.head()
# Out:
# /tmp/ipykernel_98327/514563164.py:3: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(datasets/df_file)
#    LoanNr_ChkDgt                           Name          City State    Zip  \
# 0     1000014003                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1     1000024006    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2     1000034009          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3     1000044001  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4     1000054004    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState   NAICS ApprovalDate ApprovalFY  \
# 0               FIFTH THIRD BANK        OH  451120    28-Feb-97       1997
# 1                1ST SOURCE BANK        IN  722410    28-Feb-97       1997
# 2        GRANT COUNTY STATE BANK        IN  621210    28-Feb-97       1997
# ...

# %%
df.shape
# Out:
# (899164, 27)

# %%
jq.dqr_cat(df)
# Out:
# The categorical features are:
# ['Name', 'City', 'State', 'Bank', 'BankState', 'ApprovalDate', 'ApprovalFY', 'RevLineCr', 'LowDoc', 'ChgOffDate', 'DisbursementDate', 'DisbursementGross', 'BalanceGross', 'MIS_Status', 'ChgOffPrinGr', 'GrAppv', 'SBA_Appv']
# Data Quality Report for Categorical Features
# ...
# Stats
# -----
#               Feature   Count  Missing  % Missing  Cardinality
# 0                Name  899150       14       0.00       779584
# 1                City  899134       30       0.00        32582
# 2               State  899150       14       0.00           52
# 3                Bank  897605     1559       0.17         5803
# 4           BankState  897598     1566       0.17           57
# 5        ApprovalDate  899164        0       0.00         9859
# 6          ApprovalFY  899164        0       0.00           70
# 7           RevLineCr  894636     4528       0.51           19
# 8              LowDoc  896582     2582       0.29            9
# ...

# %%
jq.dqr_cont(df)
# Out:
# The non-categorical features are:
# ['LoanNr_ChkDgt', 'Zip', 'NAICS', 'Term', 'NoEmp', 'NewExist', 'CreateJob', 'RetainedJob', 'FranchiseCode', 'UrbanRural']
# Data Quality for Continous Features
# Total Features: 10
#          Feature   Count  Missing  % missing  Cardinality
# 0  LoanNr_ChkDgt  899164        0       0.00       899164
# 1            Zip  899164        0       0.00        33611
# 2          NAICS  899164        0       0.00         1312
# 3           Term  899164        0       0.00          412
# 4          NoEmp  899164        0       0.00          599
# 5       NewExist  899028      136       0.02            4
# 6      CreateJob  899164        0       0.00          246
# 7    RetainedJob  899164        0       0.00          358
# 8  FranchiseCode  899164        0       0.00         2768
# 9     UrbanRural  899164        0       0.00            3
#
#
# Descriptive Stats
#                   count          mean           std           min  \
# ...
